# %% [markdown]
# # It is so good to be here

# %%
# all the imports
import pandas as pd
import numpy

# %%
# lets print
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
